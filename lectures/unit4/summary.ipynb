# %% [markdown]
# ### [GAIA](https://huggingface.co/learn/agents-course/en/unit4/what-is-gaia)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://github.com/huggingface/smolagents/tree/main/examples/open_deep_research

# %% [markdown]
# https://huggingface.co/spaces/agents-course/Final_Assignment_Template/blob/main/app.py
